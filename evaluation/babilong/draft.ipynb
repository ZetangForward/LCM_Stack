# %%
with open("./nohup.log","r") as f:
    print(f.read())
# Out:
# 2025-02-06 01:37:46.406 | INFO     | modelzipper.tutils:auto_mkdir:340 - ./results already exists!
#
# tasks:   0%|          | 0/5 [00:00<?, ?it/s]
#
# lengths:   0%|          | 0/8 [00:00<?, ?it/s]
#
#
# ...
# task: qa1 length: 0k: 100%|██████████| 100/100 [00:00<00:00, 1142.01it/s]
#
#
# lengths:  12%|█▎        | 1/8 [00:14<01:40, 14.32s/it]
#
#
# task: qa1 length: 1k:   0%|          | 0/100 [00:00<?, ?it/s]
#
#
# task: qa1 length: 1k:  49%|████▉     | 49/100 [00:00<00:00, 487.96it/s]
#
#
# ...
# task: qa1 length: 1k: 100%|██████████| 100/100 [00:00<00:00, 493.87it/s]
#
#
# lengths:  25%|██▌       | 2/8 [00:17<00:46,  7.74s/it]
#
#
# task: qa1 length: 2k:   0%|          | 0/100 [00:00<?, ?it/s]
#
#
# task: qa1 length: 2k:  25%|██▌       | 25/100 [00:00<00:00, 244.67it/s]
#
#
# task: qa1 length: 2k:  51%|█████     | 51/100 [00:00<00:00, 250.53it/s]
#
#
# ...
# task: qa1 length: 2k: 100%|██████████| 100/100 [00:00<00:00, 248.80it/s]
#
#
# lengths:  38%|███▊      | 3/8 [00:19<00:26,  5.33s/it]
#
#
# ...
